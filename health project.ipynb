# %%
import sys,time,random
from IPython.display import Image,display
from IPython.display import Audio
from IPython.display import YouTubeVideo

# %%
def breastcancer():
    from IPython.display import Image,display                        
    url='https://i0.wp.com/post.medicalnewstoday.com/wp-content/uploads/sites/3/2020/01/signs-of-breast-cancer-infographic.jpg'
    display(Image(url,width=400, height=500))
    print("               ")
    print("hello"+" "+name+" you can check the symptoms of breast cancer")
    s1=input(" Do you have any new lump in breast or underarm (y/n)")
    s2=input(" is there any thickening or swelling of part of the breast (y/n)")
    s3=input(" Irritation or dimpling of breast skin (y/n)")
    s4=input(" is there redness or flaky skin in the nipple area or the breast (y/n)")
    s5=input(" is there any change in the size or the shape of the breast (y/n)")
    s6=input(" Pain in any area of the breast (y/n)")
    s7=input(" is nipple discharge other than breast milk, including blood (y/n)")
    print("                     ")
    if(s1 =='y' and s2 =='y' and s3 =='y' and s4 =='y' and s5 =='y' and s6 =='y' and s7 =='y'):
        time.sleep(1)
        print("you have all the symptoms of breast cancer. Don't worry .please contact doctor and check it  ")
        
        
    elif(s1 =='y' and s7 =='y' and s5 =='y' and s2 =='n' and s3 =='n' and s4 =='n' and s6 =='n'):
        time.sleep(1)
        print(" you have symptoms.Don't worry . please contact doctor and check it ")
        
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print(" Don't worry. You don't have any symptoms of breast cancer")
        
    elif(s1 =='y' and s2 =='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print(" you have very very less chance of breat cancer. For your satisfaction you can check it")
    
    elif(s1=='n' and s2=='y' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print("you have very very less chance of breast cancer. For your satisfaction you can check it")
        
    
    elif(s1=='n' and s2=='n' and s3=='y' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print("you have very very less chance of breast cancer. For your satisfaction you can check it")
    
    elif(s1=='n' and s2=='y' and s3=='n' and s4=='y' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print("you have very very less chance of breast cancer. For your satisfaction you can check it")
        
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='y' and s6=='n' and s7=='n'):
        time.sleep(1)
        print("you have very very less chance of breast cancer. For your satisfaction you can check it")
        
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='y' and s7=='n'):
        time.sleep(1)
        print("you have very very less chance of breast cancer. For your satisfaction you can check it")
        
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='y'):
        time.sleep(1)
        print("you have very very less chance of breast cancer. For your satisfaction you can check it")
    
    else:
        time.sleep(1)
        print("you have less chance. But you can check for your satisfaction")

# %%
def osteoporosis():
    from IPython.display import Image, display                       
    url='https://d3b6u46udi9ohd.cloudfront.net/wp-content/uploads/2019/01/07071211/Osteoporosis.jpg'
    display(Image(url,width=400, height=500))
    print("        ")
    print("hello"+" "+name+" you can check the symptoms of osteoporosis")
    s1=input("do you have backpain (y/n)")
    s2=input("Loss of height over time (y/n)")
    s3=input("Any stooped posture feeling (y/n)")
    s4=input("Is  bone that breaks much more easily than expected (y/n)")
    print("               ")
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y'):
        time.sleep(1)
        print("You have all symptoms of osteoporosis. Please contact doctor")
        
    elif( s2=='y' ):
        time.sleep(1)
        print(" you have chance of osteoporosis. please contact doctor")
        
    elif( s4=='y'):
        time.sleep(1)
        print("you have chance of osteoporosis. Please contact doctor")
        
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n'):
        time.sleep(1)
        print("you have no chance")
    
    else:
        time.sleep(1)
        print("you have less chance")

# %%
def Alzheimer():
    from IPython.display import Image,display                        
    url='https://medlineplus.gov/ency/images/ency/fullsize/23214.jpg'
    display(Image(url,width=400, height=500))
    print("            ")

    print("hello"+" "+name+" you can check the symptoms of alzheimer")
    s1=input("do you feel Increased memory loss and confusion.  (y/n)")
    s2=input("any Difficulty with language and problems with reading, writing, and working with numbers (y/n)")
    s3=input("is there any Problems recognizing family and friends (y/n)")
    s4=input(" Inappropriate outbursts of anger (y/n)")
    s5=input("Impulsive behavior such as undressing at inappropriate times or places or using vulgar language (y/n)")
    s6=input("Inability to learn new things")
    s7=input("Repetitive statements or movement, occasional muscle twitches (y/n)")
    print("         ")
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print("Have all the symptoms of Alzheimer")
    
    elif(s1=='y'):
        time.sleep(1)
        print("it is  alzheimer")
        
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print(" No chance of alzheimer")
    
    else:
        time.sleep(1)
        print("can be the chance of alzheimer ")

# %%
def urt():
    print("hello"+" "+name+" you can check the symptoms of urinary tract infection")
    from IPython.display import Image,display                        
    url='https://d1zxene68j3keg.cloudfront.net/sites/default/files/Resouces/images/UTI%20image.jpg'
    display(Image(url,width=400, height=500))
    
    s1=input("do you have a strong, persistent urge to urinate (y/n)")
    s2=input(" do you feel a burning sensation when urinating (y/n)")
    s3=input(" Passing frequent, small amounts of urine (y/n)")
    s4=input(" is your Urine  appears cloudy (y/n)")
    s5=input(" is your Urine that appears red, bright pink or cola-colored (y/n)")
    s6=input(" is your urine have strong smell (y/n)")
    s7=input(" is there Pelvic pain (y/n)")
    print("   ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print("You have all the symptoms of urinart tract infection. please contact doctor")
    
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print(" you don't have any symptoms. Don't worry")
    
    else:
        time.sleep(1)
        print(" you have chances. For confirmation. you can check")

# %%
def Arthritis():
    from IPython.display import Image,display                      
    url='https://upload.wikimedia.org/wikipedia/commons/7/70/Rheumatoid_Arthritis.JPG'
    display(Image(url,width=400, height=500))
    print("     ")
    print("hello"+" "+name+" you can check the symptoms of Arthritis")
    s1=input(" do you have pain in any joints (y/n)")
    s2=input(" do you have stiffnes in joints (y/n)")
    s3=input(" do you feel decreased range of motion of joints (y/n)")
    s4=input(" is there redness on joints (y/n)")
    print("    ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y'):
        time.sleep(1)
        print(" you have arthritis on joints. Please contact doctor")
        
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n'):
        time.sleep(1)
        print(" you don't have arthritis")
    
    else:
        time.sleep(1)
        print(" it can be a chance of arthritis. so confirm by checking soon")

# %%
def svd():
    from IPython.display import Image, display                      
    url='https://www.frontiersin.org/files/Articles/441783/fphys-10-01317-HTML-r1/image_m/fphys-10-01317-g001.jpg'
    display(Image(url,width=400, height=500))
    print("                        ")
    print("hello"+" "+name+" you can check the symptoms of small vessel disease")
    s1=input("do you have chest pain (y/n)")
    s2=input(" do you feel discomfort in the left arm, jaw, neck, back or abdomen (y/n)")
    s3=input(" do you feel shortness of breath (y/n)")
    s4=input(" do you feel lack of energy and get tired soon (y/n)")
    print("          ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y'):
        time.sleep(1)
        print(" you have all symptoms of small vessel disease. please contact doctor")
        
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n'):
        time.sleep(1)
        print("you don't have small vessel disease")
    
    elif(s1=='y'and s3=='y'):
        time.sleep(1)
        print("you have chance of small vessel disease. please contact doctor ")
        
    else:
        time.sleep(1)
        print("you have less chance. for your satisfaction , you can check it")

# %%
def mcs():
    from IPython.display import Image,display                        
    url='https://s3-us-west-2.amazonaws.com/utsw-patientcare-web-production/original_images/MS_myelin_685.jpg'
    display(Image(url,width=400, height=500))
    print("          ")
    print("hello"+" "+name+" you can check the symptoms of Multiple Sclerosis")
    print("y(yes) and n(No) for below symptoms")
    
    s1=input(" do you feel Numbness or weakness in one or more limbs that typically occurs on one side of your body at a time, or your legs and trunk" )
    s2=input(" do you feel Electric-shock sensations that occur with certain neck movements, especially bending the neck forward")
    s3=input(" do you feel Tremor, lack of coordination or unsteady gait")
    s4=input(" do you feel Partial or complete loss of vision, usually in one eye at a time, often with pain during eye movement")
    s5=input("do you feel Prolonged double vision ")
    s6=input(" do you feel Blurry vision")
    s7=input(" do you feel Slurred speech")
    s8=input(" do you feel fatigue or dizziness without necessary reason")
    s9=input(" do you feel any above symptoms without any reason")
    print("              ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y' and s8=='y'):
        time.sleep(1)
        print(" you have all symptoms. please contact doctor")
    elif(s9=='y'):
        time.sleep(1)
        print("you have symptom of multiple sclerosis.please contact doctor")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n' and s8=='n'):
        time.sleep(1)
        print(" Don't worry . you don't have the disease")
    elif(s9=='n'):
        time.sleep(1)
        print(" Don't worry. you don't have this disease")

# %%
def ibs():
    from IPython.display import Image,display                       
    url='https://5.imimg.com/data5/ZT/GN/SZ/GLADMIN-24692806/selection-022-500x500.png'
    display(Image(url,width=400, height=500))
    print("            ")
    
    print("hello"+" "+name+" you can check the symptoms of irritable bowel syndrome")
    
    s1=input("do you feel Abdominal pain, cramping or bloating that is related to passing a bowel movement (y/n)")
    s2=input(" any Changes in appearance of bowel movement (y/n)")
    s3=input(" any Changes in how often you are having a bowel movement (y/n)")
    s4=input(" do you feel weight loss (y/n)")
    s5=input(" do you have rectal bleeding (y/n)")
    s6=input(" do you have unexplained vomitting (y/n)")
    s7=input(" do you have Difficulty swallowing (y/n)")
    print("                    ")
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print(" you have all the symptoms of irritable bowel syndrome. please contact doctor")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print(" you don't have this disease.")
    elif(sl=='y' and s2=='y' and s3=='y'):
        time.sleep(1)
        print("you have the symptoms of this disease. please contact doctor")
    else:
        time.sleep(1)
        print("don't worry less chance for this disease")

# %%
def stroke():
    from IPython.display import Image, display                       
    url='https://static.toiimg.com/photo/msid-87343087/87343087.jpg'
    display(Image(url,width=400, height=500))
    
    print("              ")
    print("During a stroke, every minute counts! Fast treatment can lessen the brain damage that stroke can cause.")
    print("   ")
    print("hello"+" "+name+" you can check the symptoms of Multiple Stroke")
    print(" if you feel any of the symptom below go fast and meet doctor")
    
    s1=input("Sudden numbness or weakness in the face, arm, or leg, especially on one side of the body.(y/n) ")
    s2=input("Sudden confusion, trouble speaking, or difficulty understanding speech (y/n)")
    s3=input(" Sudden trouble seeing in one or both eyes (y/n)")
    s4=input("Sudden trouble walking, dizziness, loss of balance, or lack of coordination (y/n)")
    s5=input(" Sudden severe headache with no known cause (y/n)")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y'):
        time.sleep(1)
        print(" it is the symptom of  stroke. don't waste time please contact doctor soon ")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n'):
        time.sleep(1)
        print(" don't worry you don't have any symptoms of stroke")
    elif(s1=='y'):
        time.sleep(1)
        print(" There may be chance for stroke. please contact doctor")
    elif(s2=='y'):
        time.sleep(1)
        print(" There may be chance for stroke. please contact doctor")
    elif(s3=='y'):
        time.sleep(1)
        print(" There may be chance for stroke. please contact doctor")
    elif(s4=='y'):
        time.sleep(1)
        print(" There may be chance for stroke. please contact doctor")
    elif(s5=='y'):
        time.sleep(1)
        print(" There may be chance for stroke. please contact doctor")

# %%
def diabetes():
    from IPython.display import Image,display                        
    url='https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/Main_symptoms_of_diabetes.svg/400px-Main_symptoms_of_diabetes.svg.png'
    display(Image(url,width=400, height=500))
    print("              ")
    print("hello"+" "+name+" you can check the symptoms of diabetes")
     
    s1=input(" Urinate (pee) a lot, often at night (y/n)")
    s2=input("Are you very thirsty (y/n)")  
    s3=input(" Lose weight without trying (y/n)")
    s4=input("Are very hungry (y/n)")    
    s5=input("Have blurry vision (y/n) ")
    s6=input("Have numb or tingling hands or feet (y/n)")
    s7=input("Feel very tired always(y/n) ")
    s8=input("Have sores that heal slowly (y/n)")
    s9=input(" Have more infections than usual (y/n)")
    
    print("           ")
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y' and s8=='y' and s9=='y'):
        time.sleep(1)
        print(" you have all symptoms of diabetes. Please contact doctor and take medicine")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n' and s8=='n' and s9=='n'):
        time.sleep(1)
        print(" you don't have diabetes")
    elif(s1=='y' and s2=='y' and s3=='y' and s5=='y'):
        time.sleep(1)
        print(" you have symptoms of diabetes. Please contact doctor and take medicine")
    elif(s1=='y' and s3=='y'):
        time.sleep(1)
        print(" There is chance of diabetes. Please contact doctor and take medicine")
    else:
        time.sleep(1)
        print("Less chance of diabetes. But you have some symptoms you can check and confirm it.")

# %%
def hyperthyroidism():
    from IPython.display import Image,display                        
    url='https://c8.alamy.com/comp/RB4J9K/medical-illustration-of-the-main-symptoms-of-hyperthyroidism-RB4J9K.jpg'
    display(Image(url,width=400, height=500))
    time.sleep(1)
    print("hello"+" "+name+" you can check the symptoms of hyperthyroidism")
    print("         ")
    print(" This disease is also called overactive thyroid")
    print("           ")
    
    s1=input("Experiencing anxiety, irritability and nervousness (y/n)")
    s2=input(" Having trouble sleeping (y/n)")
    s3=input(" do you lose weight (y/n)")
    s4=input(" Feeling sensitive to heat (y/n)")
    s5=input("Having vision problems or eye irritation (y/n)")
    s6=input(" Experiencing irregular menstrual periods or having your menstrual cycle stop.(y/n)")
    s7=input("Having muscle weakness and tremors (y/n)")
    
    print("                   ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print(" You have hyperthyroid. Please contact doctor and take medicine")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print(" you don't have hyperthyroid disease. ")
    elif(s2=='y' and s3=='y' and s4=='y'):
        time.sleep(1)
        print(" You have symptoms of hyperthyroid. Please take blood test and confirm it")
    elif(s3=='y' and s4=='y'):
        time.sleep(1)
        print("You have symptoms of hyperthyroid. Please take blood test and confirm it")
        
    else:
        time.sleep(1)
        print("Less chance. But you can take blood test and confirm it")

# %%
def hypothyroidism():
    from IPython.display import Image,display                        
    url='https://images.hindustantimes.com/img/2022/02/11/1600x900/pjimage_(74)_1644556562132_1644556579455.jpg'
    display(Image(url,width=400, height=500))
    print("             ")
    time.sleep(1)
    print("hello"+" "+name+" you can check the symptoms of hypothyroidism")
    print("                 ")
    
    s1=input("Feeling tired (y/n)")
    s2=input("Gaining weight (y/n)")
    s3=input("Experiencing forgetfulness (y/n)")
    s4=input("Having frequent and heavy menstrual periods (y/n)")
    s5=input("Having dry and coarse hair (y/n)")
    s6=input(" Having a hoarse voice (y/n)")
    s7=input(" Experiencing an intolerance to cold temperatures (y/n)")
    print("             ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print("You have all symptoms of hypothyroidism. Please contact doctor and take medicine")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print(" you don't have hypothyroidism")
    elif(s2=='y' and s4=='y' and s7=='y'):
        time.sleep(1)
        print(" you have symptoms of hypothyroidism. please take blood test and confirm it")
    else:
        time.sleep(1)
        print("less chance of hypothyroidism. But you can check it by blood test")

# %%
def menopause():
    from IPython.display import Image,display                        
    url='https://en.pimg.jp/076/515/065/1/76515065.jpg'
    display(Image(url,width=400, height=500))
    print("        ")
    time.sleep(1)
    print("hello"+" "+name+" you can check the symptoms of menopause")
    print("                 ")
    
    s1=input("Irregular periods (y/n)")
    s2=input(" Sleep problems (y/n)")
    s3=input("Vaginal dryness (y/n)")
    s4=input(" Thinning hair and dry skin (y/n)")
    s5=input("Weight gain and slowed metabolism (y/n)")
    s6=input("Mood changes (y/n)")
    s7=input("Loss of breast fullness (y/n)")
    print("             ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print("it is menopause.")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print(" it's not menopause")
    else:
        time.sleep(1)
        print("less chance")

# %%
def autoimmune():
    from IPython.display import Image,display                        
    url='https://www.niehs.nih.gov/health/assets/images/autoimmune_disease.jpg'
    display(Image(url,width=400, height=500))
    print("            ")
    time.sleep(1)
    
    print("hello"+" "+name+" you can check the symptoms of Autoimmune disease")
    print("             ")
    
    s1=input(" do you feel tired always(y/n)")
    s2=input("do you have joint pain (y/n)")
    s3=input(" do you have skin problem (y/n)")
    s4=input(" Abdominal pain or digestive issues (y/n)")
    s5=input("Recurring fever (y/n)")
    print("              ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y'):
        time.sleep(1)
        print(" You have autoimmune disease")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n'):
        time.sleep(1)
        print(" you don't have autoimmune disease")
    elif(s1=='y' and s4=='y' and s5=='y'):
        time.sleep(1)
        print(" you have a chance of autoimmune disease")
    else:
        time.sleep(1)
        print("Less chance. But you can check")

# %%
def endometriosis():
    from IPython.display import Image,display                        
    url='https://www.mayoclinic.org/-/media/kcms/gbs/patient-consumer/images/2013/11/15/17/37/ds00289_-my00554_im00303_w7_endometriosisthu_jpg.jpg'
    display(Image(url,width=400, height=500))
    print("         ")
    time.sleep(1)
    
    print("hello"+" "+name+" you can check the symptoms of Endometriosis disease")
    
    s1=input(" do you have painful period (y/n)")
    s2=input("do you have Pain with bowel movements or urination (y/n)")
    s3=input("do you have exceesive bleeding during period(y/n)")
    s4=input("do you feel fatigue, diarrhea during menstrual period (y/n)")
    
    print("    ")
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y'):
        time.sleep(1)
        print(" You have Endometriosis disease")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n'):
        time.sleep(1)
        print("you don't have Endometriosis disease")
    elif(s1=='y' and s2=='y' and s4=='y'):
        time.sleep(1)
        print(" There is a chance of Endometriosis")
    else:
        time.sleep(1)
        print("Less chance. But you can contact doctor and check it")

# %%
def uterinefibroid():
    from IPython.display import Image,display                        
    url='https://preferredvasculargroup.com/wp-content/uploads/2020/01/Preferred-Vascular_Uterine-Fibroids.png'
    display(Image(url,width=400, height=500))
    time.sleep(1)
    print("           ")
    print("hello"+" "+name+" you can check the symptoms of uterine fibroid disease")
    print("             ")
    
    s1=input("Heavy menstrual bleeding (y/n) ")
    s2=input("Menstrual periods lasting more than a week (y/n)")
    s3=input("Pelvic pressure or pain (y/n)")
    s4=input(" Frequent urination (y/n)")
    s5=input("Difficulty emptying the bladder (y/n)")
    s6=input("Backache or leg pains (y/n)")
   
    print("        ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' ):
        time.sleep(1)
        print(" You have uterine fibroid disease. please contact doctor")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' ):
        time.sleep(1)
        print("you don't have disease")
    elif(s1=='y' and s2=='y' and s3=='y' and s5=='y'):
        time.sleep(1)
        print(" You have the chance of uterine fibroid disease")
    else:
        time.sleep(1)
        print("less chance. But for confirmation you can take test")

# %%
def ic():
    from IPython.display import Image,display                        
    url='https://whsfl.com/wp-content/uploads/2019/07/bladder-diagram.jpg'
    display(Image(url,width=400, height=500))
    time.sleep(1)
    print("           ")
    print("hello"+" "+name+" you can check the symptoms of Interstitial cystitis disease")
    print("             ")
    
    s1=input(" Pain in your pelvis or between the vagina and anus in women (y/n)")
    s2=input("A persistent, urgent need to urinate (y/n)")
    s3=input(" Pain or discomfort while the bladder fills and relief after urinating (y/n)")
    s4=input("Frequent urination, often of small amounts, throughout the day and night (up to 60 times a day) (y/n)")
    s5=input("Chronic pelvic pain (y/n)")
    print("              ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y'):
        time.sleep(1)
        print(" You have Interstitial Cystitis Disease. Please contact doctor soon")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n'):
        time.sleep(1)
        print(" You don't have Interstitial disease")
    elif(s2=='y' and s4=='y' and s3=='y'):
        time.sleep(1)
        print(" You have symptoms of Interstitial disease. Please contact doctor")
    else:
        time.sleep(1)
        print(" Less chance")

# %%
def pcos():
    from IPython.display import Image,display                        
    url='https://www.mayoclinic.org/-/media/kcms/gbs/patient-consumer/images/2013/08/26/10/42/ds00423_im04151_mcdc7_polycystic_ovarythu_jpg.jpg'
    display(Image(url,width=400, height=500))
    time.sleep(1)
    print("           ")
    print("hello"+" "+name+" you can check the symptoms of Polycystic ovary syndrome")
    print("             ")
    
    s1=input(" Irregular periods (y/n)")
    s2=input("Excessive hair growth on face, chest, neck (y/n)")
    s3=input("weight gain (y/n)")
    s4=input("thinning hair and hair loss (y/n)")
    s5=input("oily skin(y/n)")
    s6=input("difficulty getting pregnant (y/n)")
    print("            ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y'):
        time.sleep(1)
        print(" You have the disease of Polycystic ovary syndrome. Please contact doctor")
        
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n'):
        time.sleep(1)
        print(" You don't have the disease of Polycystic ovary syndrome")
    elif(s1=='y' and s6=='y' and s2=='y'):
        time.sleep(1)
        print(" You have the chance of Polystic ovary syndrome")
    else:
        time.sleep(1)
        print(" Less chance")

# %%
def cad():
    from IPython.display import Image,display                        
    url='https://www.cdc.gov/heartdisease/images/coronary-artery-disease-medium.jpg'
    display(Image(url,width=400, height=500))
    time.sleep(1)
    print("           ")
    print("hello"+" "+name+" you can check the symptoms of Coronary artery disease")
    print("             ")
    
    s1=input("do you have Chest pain (y/n) ")
    s2=input("Weakness, light-headedness, nausea (feeling sick to your stomach), or a cold sweat (y/n)")
    s3=input("Pain or discomfort in the arms or shoulder (y/n)")
    s4=input("Shortness of breath (y/n)")
    print("         ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y'):
        time.sleep(1)
        print("All the symptoms of coronary artery disease. Please contact doctor soon. Don't waste  time")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n'):
        time.sleep(1)
        print("You don't have symptoms of coronary aetery disease. Don't worry")
    elif(s1=='y'):
        time.sleep(1)
        print("You have chest pain. it is not good. So contact doctor")
    else:
        time.sleep(1)
        print(" Less chance")

# %%
def mi():
    from IPython.display import Image,display                        
    url='https://www.mayoclinic.org/-/media/kcms/gbs/patient-consumer/images/2013/08/26/11/01/ds01179_im03129_mcdc7_myocardialischemia_jpg.png'
    display(Image(url,width=400, height=500))
    time.sleep(1)
    print("           ")
    print("hello"+" "+name+" you can check the symptoms of Myocardial ischemia")
    print("             ")
    
    s1=input("Neck or jaw pain (y/n)")
    s2=input("Shoulder or arm pain (y/n)")
    s3=input("A fast heartbeat (y/n)")
    s4=input("Shortness of breath when you are physically active (y/n)")
    s5=input("Nausea and vomiting (y/n)")
    s6=input("feel tired (y/n)")
    s7=input("chest pain (y/n)")
    print("       ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print("You have the symptoms of Myocardial ischemia. Please contact doctor")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print("You don't have Myocardial ischemia")
    elif(s3=='y' and s4=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print("There are symptoms of Myocardial ischemia")
    elif(s7=='y'):
        time.sleep(1)
        print("Chest pain is not good. It can be of any heart disease may or may be. Please contact doctor")
    elif(s3=='y' and s4=='y'):
        time.sleep(1)
        print(" You want to meet doctor")
    else:
        time.sleep(1)
        print("less chance")

# %%
def chd():
    url1='https://media.healthdirect.org.au/images/inline/original/congenital-heart-disease-examples-e4af20.gif'
    display(Image(url1,width=400, height=500))
    time.sleep(1)
    
    print("           ")
    print("hello"+" "+name+" you can check the symptoms of congenital heart disease")
    print("             ")
    
    s1=input("rapid heartbeat  (y/n)")
    s2=input(" rapid breathing (y/n)")
    s3=input(" swelling of the legs, tummy or around the eyes (y/n)")
    s4=input("extreme tiredness and fatigue (y/n)")
    s5=input("a blue tinge to the skin or lips (y/n)")
    s6=input("tiredness and rapid breathing when a baby is feeding (y/n)")
    s7=input("do you have chest pain (y/n)")
    print("            ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print(" It is congential heart disease")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print("Don't worry. You don't have this disease")
    elif(s1=='y' and s2=='y' and s4=='y' and s7=='y'):
        time.sleep(1)
        print("You have chance of congential heart disease")
        
    elif(s1=='y' and s5=='y' and s7=='y'):
        time.sleep(1)
        print("There is chance of congential heart disease. Please contact doctor")
    elif(s1=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print("There is a chance of congential heart disease. Please contact doctor")
    else:
        time.sleep(1)
        print("Less chance.")

# %%
def cervical():
    url1='https://nuawoman.com/blog/wp-content/uploads/2019/01/cervical-cancer.jpg'
    display(Image(url1,width=400, height=500))
    time.sleep(1)
    
    print("           ")
    print("hello"+" "+name+" you can check the symptoms of cervical cancer")
    print("             ")
    
    s1=input("Vaginal bleeding after intercourse, between periods or after menopause (y/n)")
    s2=input("Watery, bloody vaginal discharge that may be heavy and have a foul odor (y/n)")
    s3=input("Pelvic pain or pain during intercourse (y/n)")
    
    if(s1=='y' and s2=='y' and s3=='y'):
        time.sleep(1)
        print(" You have all symptoms of cervical cancer. Please contact doctor")
    elif(s1=='n' and s2=='n' and s3=='n'):
        time.sleep(1)
        print("You don't have cervical cancer")
    elif(s1=='y'):
        time.sleep(1)
        print("You have chance of cervical cancer. Please contact doctor and confirm it")
    elif(s2=='y'):
        time.sleep(1)
        print("You have chance of cervical cancer. Please contact doctor and confirm it")
    else:
        time.sleep(1)
        print("Less chance")

# %%
def poi():
    url1='https://www.indiraivf.com/wp-content/uploads/2018/05/Premature-Ovarian-Failure.jpg'
    display(Image(url1,width=400, height=500))
    time.sleep(1)
    
    print("           ")
    print("hello"+" "+name+" you can check the symptoms of Primary ovarian insufficiency")
    print("             ")
    
    s1=input("Irregular or skipped periods (y/n)")
    s2=input("Difficulty getting pregnant (y/n)")
    s3=input("Hot flashes (y/n)")
    s4=input("Night sweats (y/n)")
    s5=input(" Vaginal dryness (y/n)")
    s6=input("Dry eyes (y/n)")
    s7=input("Irritability or difficulty concentrating (y/n)")
    print("                ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print("You have all symptoms of primary ovarian insufficency")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print("You don't have primary ovarian insufficency")
    elif(s1=='y' and s2=='y'):
        time.sleep(1)
        print("please contact doctor")
    else:
        time.sleep(1)
        print("Less chance")

# %%
def chlamydia():
    url1='https://cdn.w600.comps.canstockphoto.com/chlamydia-infection-eps-vector_csp53986948.jpg'
    display(Image(url1,width=400, height=500))
    time.sleep(1)
    
    print("           ")
    print("hello"+" "+name+" you can check the symptoms of Chlamydia")
    print("             ")
    
    s1=input("burning sensation during urination (y/n)")
    s2=input("pain in the lower abdomen (y/n)")
    s3=input("bleeding between periods (y/n) ")
    s4=input("inflammation of the cervix (y/n)")
    s5=input("Abnormal vaginal discharge that may have an odor (y/n)")
    s6=input("Abdominal pain with fever (y/n)")
    s7=input("Pain when you have sex (y/n)")
    print("           ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print("You have all symptoms of chlamydia. please contact doctor")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print("You don't have chlamydia")
    elif(s5=='y' and s2=='y'):
        time.sleep(1)
        print("You have chance of chlamydia")
    else:
        time.sleep(1)
        print("less chance")

# %%
def pid():
    url1='https://assets.lybrate.com/q_auto,f_auto,w_1200/imgs/dt/tp/0273345e6919ca07337bb201c8da99df/1d4cc6263272feec10b46a1ef35ecd28/bbefdf.jpg'
    display(Image(url1,width=400, height=500))
    time.sleep(1)
    
    print("           ")
    print("hello"+" "+name+" you can check the symptoms of Pelvic inflammatory disease")
    print("             ")
    
    s1=input("Pain — ranging from mild to severe — in your lower abdomen and pelvis (y/n)")
    s2=input("Abnormal or heavy vaginal discharge that may have an unpleasant odor (y/n)")
    s3=input("Abnormal uterine bleeding, especially during or after intercourse, or between menstrual cycles (y/n)")
    s4=input("Pain during intercourse (y/n)")
    s5=input("Fever, sometimes with chills (y/n)")
    s6=input("Painful, frequent or difficult urination (y/n)")
    s7=input("Nausea and vomiting (y/n)")
    print("          ")
    
    if(s1=='y' and s2=='y' and s3=='y' and s4=='y' and s5=='y' and s6=='y' and s7=='y'):
        time.sleep(1)
        print("You have pelvic inflammatory disease. Please contact doctor")
    elif(s1=='n' and s2=='n' and s3=='n' and s4=='n' and s5=='n' and s6=='n' and s7=='n'):
        time.sleep(1)
        print("You don't have pelvic inflammatory disease")
    elif(s1=='y' and s7=='y' and s5=='y'):
        time.sleep(1)
        print("you have chance of pelvic inflammatory disease")
    else:
        time.sleep(1)
        print("You have less chance")

# %%
from IPython.display import Image,display                       
url='https://thumbs.dreamstime.com/b/good-health-best-wealth-card-stethoscope-red-heart-wood-table-medical-concept-72050180.jpg'

display(Image(url,width=400, height=500))
print("Hi")


time.sleep(1)
print("            ")
print("welcome to your health checking")
print("         ")
print(" All women should take care of their health")

print("           ")
print(" if we find disease early we can defeat the disease")
time.sleep(1)

from IPython.display import Image,display                        
url2='https://arizonahealthspot.files.wordpress.com/2013/05/womens-health.gif'
display(Image(url2,width=400, height=500))

time.sleep(.5)
print("             ")
name =input("enter name ")

time.sleep(.5)
print("          ")

print("Hi "+ name+ " you can check the symptoms of following diseases")
time.sleep(1)
print("  ")

print("1. Breast cancer")
print("  ")

print("2. osteoporosis")
print("     ")

print("3. Alzheimer’s")
print("         ")

print("4. Urinary tract infection")
print("           ")

print("5. Arthritis")
print("         ")

print("6. Small Vessel Disease")
print("             ")

print("7. Multiple Sclerosis")
print("                   ")

print("8. Irritable bowel syndrome ")
print("             ")

print("9. stroke")
print("               ")

print("10. Diabetes")
print("                ")

print("11. Hyperthyroidism")
print("         ")

print("12. Hypothyroidism")
print("         ")

print("13. Menopause")
print("Menopause is the time that marks the end of your menstrual cycles")
print("           ")

print("14. Autoimmune disease")
print("Autoimmune diseases are a group of disorders in which the immune system attacks the body and destroys or alters tissues.")
print("             ")

print("15. Endometriosis")
print("Endometriosis is a problem affecting a woman’s uterus.")
print("Endometriosis is when the kind of tissue that normally lines the uterus grows somewhere else")
print(" It can grow on the ovaries, behind the uterus, on the bowels, or on the bladder.")
print("          ")

print("16. Uterine fibroids")
print("Uterine fibroids are the most common noncancerous tumors in women of childbearing age.")
print("Fibroids are made of muscle cells and other tissues that grow in and around the wall of the uterus, or womb.")
print("            ")

print("17.Interstitial cystitis")
print("It is a chronic condition causing bladder pressure, bladder pain and sometimes pelvic pain. ")
print("The condition is a part of a spectrum of diseases known as painful bladder syndrome.")
print("                      ")

print("18.Polycystic ovary syndrome")
print("Polycystic ovary syndrome happens when a woman’s ovaries or adrenal glands produce more male hormones than normal.")
print("         ")

print(" 19. coronary artery disease")
print("            ")

print("20. Myocardial ischemia")
print("Myocardial ischemia occurs when blood flow to your heart is reduced, preventing the heart muscle from receiving enough oxygen")
print("Myocardial ischemia, also called cardiac ischemia, reduces the heart muscle's ability to pump blood.")
print("             ")

print("21. Congenital heart disease")
print("Congenital heart disease is a general term for a range of birth defects that affect the normal way the heart works.")
print("The term congenital means the condition is present from birth.")
print("                    ")

print("22. Cervical Cancer")
print("Long-lasting infection with certain types of human papillomavirus (HPV) is the main cause of cervical cancer")
print("              ")

print("23. Primary Ovarian Insufficiency")
print("Primary ovarian insufficiency occurs when the ovaries stop functioning as they should before age 40.")
print(" This condition is also called premature ovarian failure and often leads to infertility.")
print("       ")

print("24. Chlamydia ")
print(" Chlamydia is a common sexually transmitted infection (STI) caused by bacteria.")
print(" ")

print("25. Pelvic inflammatory disease")
print("Pelvic inflammatory disease (PID) is an infection of the female reproductive organs.")
print("It most often occurs when sexually transmitted bacteria spread from your vagina to your uterus, fallopian tubes or ovaries")
print("                 ")

while(True):
    sym=int(input(" You want to look for the symptoms of which disease (write number like 1 for breast cancer etc ) "))
    if(sym==1):
        breastcancer()
    elif(sym==2):
        osteoporosis()
    elif(sym==3):
        Alzheimer()
    elif(sym==4):
        urt()
    elif(sym==5):
        Arthritis()
    elif(sym==6):
        svd()
    elif(sym==7):
        mcs()
    elif(sym==8):
        ibs()
    elif(sym==9):
        stroke()
    elif(sym==10):
        diabetes()
    elif(sym==11):
        hyperthyroidism()
    elif(sym==12):
        hypothyroidism()
    elif(sym==13):
        menopause()
    elif(sym==14):
        autoimmune()
    elif(sym==15):
        endometriosis()
    elif(sym==16):
        uterinefibroid()
    elif(sym==17):
        ic()
    elif(sym==18):
        pcos()
    elif(sym==19):
        cad()
    elif(sym==20):
        mi()
    elif(sym==21):
        chd()
    elif(sym==22):
        cervical()
    elif(sym==23):
        poi()
    elif(sym==24):
        chlamydia()
    elif(sym==25):
        pid()
    else:
        print(" you selected which is not on the list. sorry")
    cont=input("do you want to continue for looking symptoms of another disease(y/n)")
    if(cont=='n'):
        print("Thank you for using our application")
        url1='https://thumbs.dreamstime.com/b/thank-you-lettering-blurred-lights-background-thank-you-lettering-102011881.jpg'
        display(Image(url1,width=400, height=500))

        break
# Out:
# Hi
#
# welcome to your health checking
#
#  All women should take care of their health
#
#  if we find disease early we can defeat the disease
#
# enter name retsy
#
# Hi retsy you can check the symptoms of following diseases
#
# 1. Breast cancer
#
# 2. osteoporosis
#
# 3. Alzheimer’s
#
# 4. Urinary tract infection
#
# 5. Arthritis
#
# 6. Small Vessel Disease
#
# 7. Multiple Sclerosis
#
# 8. Irritable bowel syndrome
#
# 9. stroke
#
# 10. Diabetes
#
# 11. Hyperthyroidism
#
# 12. Hypothyroidism
#
# 13. Menopause
# Menopause is the time that marks the end of your menstrual cycles
#
# 14. Autoimmune disease
# Autoimmune diseases are a group of disorders in which the immune system attacks the body and destroys or alters tissues.
#
# 15. Endometriosis
# Endometriosis is a problem affecting a woman’s uterus.
# Endometriosis is when the kind of tissue that normally lines the uterus grows somewhere else
#  It can grow on the ovaries, behind the uterus, on the bowels, or on the bladder.
#
# ...
